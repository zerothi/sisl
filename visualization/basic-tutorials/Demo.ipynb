# %% [markdown]
# # First steps

# %%
import sisl

# We define the root directory where our files are
siesta_files = sisl.get_environ_variable("SISL_FILES_TESTS") / "siesta"

# %% [markdown]
# ## Your first plots
#
# The most straightforward way to plot things in sisl is to call their `plot` method. For example if we have the path to a bands file we can call plot:

# %%
sisl.get_sile(siesta_files / "SrTiO3" / "unpolarized" / "SrTiO3.bands").plot()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="6736f409-e59e-4603-8889-0340e5f1d3d4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6736f409-e59e-4603-8889-0340e5f1d3d4")) {                    Plotly.newPlot(                        "6736f409-e59e-4603-8889-0340e5f1d3d4",                        [{"legendgroup":"Bands","line":{"color":"black","dash":"solid","width":1},"meta":{},"mode":"lines","name":"Bands","opacity":1,"x":{"dtype":"f8","bdata":"AAAAAAAAAAA5mE2AYfmTPzmYTYBh+aM\u002fVmR0QBL2rT85mE2AYfmzP0j+YOC597g\u002fVmR0QBL2vT8y5UNQNXrBPzmYTYBh+cM\u002fQEtXsI14xj9I\u002fmDguffIP0+xahDmdss\u002fVmR0QBL2zT+vCz84nzrQPzLlQ1A1etE\u002ftr5IaMu50j85mE2AYfnTP71xUpj3ONU\u002fQEtXsI141j\u002fEJFzII7jXP0j+YOC599g\u002fy9dl+E832j9PsWoQ5nbbPwBzLVqAttw\u002fg0wychb23T8HJjeKrDXfP8X\u002fHVGhOuA\u002fh2wgXWza4D9J2SJpN3rhPwtGJXUCGuI\u002fzLIngc254j+OHyqNmFnjP1CMLJlj+eM\u002fEvkupS6Z5D\u002fUZTGx+TjlP5XSM73E2OU\u002fVz82yY945j8ZrDjVWhjnP9sYO+EluOc\u002fnYU97fBX6D9e8j\u002f5u\u002ffoPyBfQgWHl+k\u002f4stEEVI36j+kOEcdHdfqP2WlSSnodus\u002fBP9byY4N7D+6TE2CN6TsP1mmXyLeOu0\u002fDvRQ24bR7T+tTWN7LWjuP2ObVDTW\u002fu4\u002fAvVm1HyV7z9cIazGEhbwPytOtRZmYfA\u002fBvUtc7qs8D\u002fVITfDDfjwP6VOQBNhQ\u002fE\u002ff\u002fW4b7WO8T9PIsK\u002fCNrxPyrJOhxdJfI\u002f+fVDbLBw8j\u002fUnLzIBLzyP6PJxRhYB\u002fM\u002ffnA+daxS8z9OnUfF\u002f53zPx3KUBVT6fM\u002f+HDJcac09D\u002fHndLB+n\u002f0P6JESx5Py\u002fQ\u002fcXFUbqIW9T9MGM3K9mH1PxxF1hpKrfU\u002f9utOd5749T\u002fGGFjH8UP2P6G\u002f0CNGj\u002fY\u002fcOzZc5na9j8\u002fGePD7CX3PxrAWyBBcfc\u002flWJH41C\u002f9z8bf6KyYQ34P5YhjnVxW\u002fg\u002fHT7pRIKp+D+Y4NQHkvf4Px79L9eiRfk\u002fmZ8bmrKT+T8UQgddwuH5P5peYizTL\u002fo\u002fFQFO7+J9+j+bHam+88v6PxbAlIEDGvs\u002fnNzvUBRo+z8Xf9sTJLb7P52bNuM0BPw\u002fGD4ipkRS\u002fD+T4A1pVKD8Pxr9aDhl7vw\u002flZ9U+3Q8\u002fT8bvK\u002fK
LZvn0DAenRyMfOeQMB7UnU6fZ5AwAqm6V4UnkDAYLQWEbKdQMBEOLXeXJ1AwO92DDoOnUDAxc34acmcQMBi350ni5xAwMar+3JTnEDAjdU1BR+cQMC4XEze7ZtAwEdBP\u002f6\u002fm0DA1SUyHpKbQMAArUj3YJtAwI+ROxczm0DAHXYuNwWbQMBI\u002fUQQ1JpAwNfhNzCmmkDAZcYq ...

# %% [markdown]
# You can pass arguments to the plotting function:

# %%
rho_file = sisl.get_sile(siesta_files / "SrTiO3" / "unpolarized" / "SrTiO3.RHO")
rho_file.plot(axes="xy", nsc=[2, 1, 1], smooth=True).show("png")
# Out:
# INFO	Task(Task-2) nodify.node.139647589498032:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592439760:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592441776:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589747504:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589491792:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589747312:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592434240:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589745680:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589491408:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589747120:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589487232:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592434528:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589496112:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589496496:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589496880:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589746784:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589490832:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592439760:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647592441776:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589747504:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589491792:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589747312:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647592434240:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589745680:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589491408:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589747120:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647592434240:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589745680:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647594273136:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589746496:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589492752:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592444032:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592434240:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589745680:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647592439760:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647592441776:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589747504:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589491792:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589747312:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647592434240:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589745680:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589491408:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589747120:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647592434240:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589745680:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647594273136:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589491792:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647657271584:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589493136:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589494192:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589494576:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589494960:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589493568:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592447824:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592439760:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589495344:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592434240:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589745680:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589495728:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592435392:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589497264:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592439760:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647592446432:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592434240:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589745680:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589491792:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589497648:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589745488:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589256272:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647591069168:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589749760:node.py:get()- Evaluated because inputs changed.

# %% [markdown]
# Some objects can be plotted in different ways, and just calling `plot` will do it in the default way. You can however **choose which plot you want** from the available representations. For example, out of a PDOS file you can plot the PDOS (the default):

# %%
pdos_file = sisl.get_sile(siesta_files / "SrTiO3" / "unpolarized" / "SrTiO3.PDOS")

pdos_file.plot(groups=[{"species": "O", "name": "O"}, {"species": "Ti", "name": "Ti"}])
# Out:
# INFO	Task(Task-2) nodify.node.139647589986960:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647591060864:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589756960:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589979088:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589829856:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589977696:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647591060864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589756960:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589976928:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647592445616:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589983120:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647594274672:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589975056:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589832112:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589828800:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589975056:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647590050192:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589828992:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589989552:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589975056:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647589836192:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589976400:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647589838256:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647590047552:node.py:get()- Evaluated because inputs changed.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="db2bf1a6-c6fe-45fd-acbb-7ee88a0cd875" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("db2bf1a6-c6fe-45fd-acbb-7ee88a0cd875")) {                    Plotly.newPlot(                        "db2bf1a6-c6fe-45fd-acbb-7ee88a0cd875",                        [{"line":{"width":1.0},"meta":{},"mode":"lines","name":"O","x":{"dtype":"f8","bdata":"gkafRaXX\u002f79aoicjNnH\u002fv1rMAP7GCv+\u002fMiiJ21ek\u002fr8uUmK26D3+vy58O5F51\u002f2\u002fBtjDbgpx\u002fb8GAp1Jmwr9vwIsdiQspPy\u002f2of+Ab09\u002fL\u002fasdfcTdf7v7INYLrecPu\u002frjc5lW8K+7+uYRJwAKT6v4a9mk2RPfq\u002fgudzKCLX+b9eQ\u002fwFs3D5v1pt1eBDCvm\u002fVpeuu9Sj+L8y8zaZZT34vy4dEHT21ve\u002fCnmYUYdw978Go3EsGAr3vwLNSgepo\u002fa\u002f3ij
u002fxWDQ\u002fPP9\u002fj\u002fFYND88\u002f3+P8Vg0Pzz\u002ff4\u002fxWDQ\u002fPP9\u002fj\u002fFYND88\u002f3+P8Vg0Pzz\u002ff4\u002fxWDQ\u002fPP9\u002fj\u002fFYND88\u002f3+P8Vg0Pzz\u002ff4\u002fxWDQ\u002fPP9\u002fj\u002fFYND88\u002f3+P8Vg0Pzz\u002ff4\u002fxWDQ\u002fPP9\u002fj\u002fFYND88\u002f3+P8Vg0Pzz\u002ff4\u002fxWDQ\u002fPP9\u002fj\u002fFYND88\u002f3+P8Vg0Pzz\u002ff4\u002fxWDQ\u002fPP9\u002fj\u002fFYND88\u002f3+PwAAAAAAAPh\u002fxWDQ\u002fPP9\u002fj8macVoYFz9P4hxutTMuvs\u002f6X ...

# %% [markdown]
# Updating your plots
# ----------------
#
# When you call `.plot()`, you receive a `Plot` object:

# %%
pdos_plot = pdos_file.plot()
type(pdos_plot)
# Out:
# sisl.viz.plots.pdos.PdosPlot

# %% [markdown]
# `Plot` objects are a kind of `Workflow`. You can check the `sisl.nodes` documentation to understand what exactly this means. But long story short, this means that the computation is split in multiple nodes, as you can see in the following diagram:

# %%
pdos_plot.network.visualize(notebook=True)
# Out:
# <div style="height:600px"><html>
#     <head>
#         <meta charset="utf-8">
#
#             <script>function neighbourhoodHighlight(params) {
#   // console.log("in nieghbourhoodhighlight");
#   allNodes = nodes.get({ returnType: "Object" });
#   // originalNodes = JSON.parse(JSON.stringify(allNodes));
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     highlightActive = true;
#     var i, j;
#     var selectedNode = params.nodes[0];
#     var degrees = 2;
#
#     // mark all nodes as hard to read.
#     for (let nodeId in allNodes) {
#       // nodeColors[nodeId] = allNodes[nodeId].color;
#       allNodes[nodeId].color = "rgba(200,200,200,0.5)";
#       if (allNodes[nodeId].hiddenLabel === undefined) {
#         allNodes[nodeId].hiddenLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#     var connectedNodes = network.getConnectedNodes(selectedNode);
#     var allConnectedNodes = [];
#
#     // get the second degree nodes
#     for (i = 1; i < degrees; i++) {
#       for (j = 0; j < connectedNodes.length; j++) {
#         allConnectedNodes = allConnectedNodes.concat(
#           network.getConnectedNodes(connectedNodes[j])
#         );
#       }
#     }
#
#     // all second degree nodes get a different color and their label back
#     for (i = 0; i < allConnectedNodes.length; i++) {
#       // allNodes[allConnectedNodes[i]].color = "pink";
#       allNodes[allConnectedNodes[i]].color = "rgba(150,150,150,0.75)";
#       if (allNodes[allConnectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[allConnectedNodes[i]].label =
#           allNodes[allConnectedNodes[i]].hiddenLabel;
#         allNodes[allConnectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // all first degree nodes get their own color and their label back
#     for (i = 0; i < connectedNodes.length; i++) {
#       // allNodes[connectedNodes[i]].color = undefined;
#       allNodes[connectedNodes[i]].color = nodeColors[connectedNodes[i]];
#       if (allNodes[connectedNodes[i]].hiddenLabel !== undefined) {
#         allNodes[connectedNodes[i]].label =
#           allNodes[connectedNodes[i]].hiddenLabel;
#         allNodes[connectedNodes[i]].hiddenLabel = undefined;
#       }
#     }
#
#     // the main node gets its own color and its label back.
#     // allNodes[selectedNode].color = undefined;
#     allNodes[selectedNode].color = nodeColors[selectedNode];
#     if (allNodes[selectedNode].hiddenLabel !== undefined) {
#       allNodes[selectedNode].label = allNodes[selectedNode].hiddenLabel;
#       allNodes[selectedNode].hiddenLabel = undefined;
#     }
#   } else if (highlightActive === true) {
#     // console.log("highlightActive was true");
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       // allNodes[nodeId].color = "purple";
#       allNodes[nodeId].color = nodeColors[nodeId];
#       // delete allNodes[nodeId].color;
#       if (allNodes[nodeId].hiddenLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].hiddenLabel;
#         allNodes[nodeId].hiddenLabel = undefined;
#       }
#     }
#     highlightActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     // console.log("Nothing was selected");
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         // console.log(allNodes[nodeId]);
#         // allNodes[nodeId].color = {};
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function filterHighlight(params) {
#   allNodes = nodes.get({ returnType: "Object" });
#   // if something is selected:
#   if (params.nodes.length > 0) {
#     filterActive = true;
#     let selectedNodes = params.nodes;
#
#     // hiding all nodes and saving the label
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = true;
#       if (allNodes[nodeId].savedLabel === undefined) {
#         allNodes[nodeId].savedLabel = allNodes[nodeId].label;
#         allNodes[nodeId].label = undefined;
#       }
#     }
#
#     for (let i=0; i < selectedNodes.length; i++) {
#       allNodes[selectedNodes[i]].hidden = false;
#       if (allNodes[selectedNodes[i]].savedLabel !== undefined) {
#         allNodes[selectedNodes[i]].label = allNodes[selectedNodes[i]].savedLabel;
#         allNodes[selectedNodes[i]].savedLabel = undefined;
#       }
#     }
#
#   } else if (filterActive === true) {
#     // reset all nodes
#     for (let nodeId in allNodes) {
#       allNodes[nodeId].hidden = false;
#       if (allNodes[nodeId].savedLabel !== undefined) {
#         allNodes[nodeId].label = allNodes[nodeId].savedLabel;
#         allNodes[nodeId].savedLabel = undefined;
#       }
#     }
#     filterActive = false;
#   }
#
#   // transform the object into an array
#   var updateArray = [];
#   if (params.nodes.length > 0) {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   } else {
#     for (let nodeId in allNodes) {
#       if (allNodes.hasOwnProperty(nodeId)) {
#         updateArray.push(allNodes[nodeId]);
#       }
#     }
#     nodes.update(updateArray);
#   }
# }
#
# function selectNode(nodes) {
#   network.selectNodes(nodes);
#   neighbourhoodHighlight({ nodes: nodes });
#   return nodes;
# }
#
# function selectNodes(nodes) {
#   network.selectNodes(nodes);
#   filterHighlight({nodes: nodes});
#   return nodes;
# }
#
# function highlightFilter(filter) {
#   let selectedNodes = []
#   let selectedProp = filter['property']
#   if (filter['item'] === 'node') {
#     let allNodes = nodes.get({ returnType: "Object" });
#     for (let nodeId in allNodes) {
#       if (allNodes[nodeId][selectedProp] && filter['value'].includes((allNodes[nodeId][selectedProp]).toString())) {
#         selectedNodes.push(nodeId)
#       }
#     }
#   }
#   else if (filter['item'] === 'edge'){
#     let allEdges = edges.get({returnType: 'object'});
#     // check if the selected property exists for selected edge and select the nodes connected to the edge
#     for (let edge in allEdges) {
#       if (allEdges[edge][selectedProp] && filter['value'].includes((allEdges[edge][selectedProp]).toString())) {
#         selectedNodes.push(allEdges[edge]['from'])
#         selectedNodes.push(allEdges[edge]['to'])
#       }
#     }
#   }
#   selectNodes(selectedNodes)
# }</script>
#             <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css" integrity="sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==" crossorigin="anonymous" referrerpolicy="no-referrer" />
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js" integrity="sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==" crossorigin="anonymous" referrerpolicy="no-referrer"></script>
#
#
#
#
#
#
#
#
# <center>
# <h1></h1>
# </center>
#
# <!-- <link rel="stylesheet" href="../node_modules/vis/dist/vis.min.css" type="text/css" />
# <script type="text/javascript" src="../node_modules/vis/dist/vis.js"> </script>-->
#         <link
#           href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css"
#           rel="stylesheet"
#           integrity="sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6"
#           crossorigin="anonymous"
#         />
#         <script
#           src="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js"
#           integrity="sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf"
#           crossorigin="anonymous"
#         ></script>
#
#
#         <center>
#           <h1></h1>
#         </center>
#         <style type="text/css">
#
#              #mynetwork {
#                  width: 100%;
#                  height: 600p

# %% [markdown]
# With that knowledge, when you update the inputs of a plot, only the necessary parts are recalculated. In that way, you may avoid repeating expensive calculations or reading to files that no longer exist. Inputs are updated with `update_inputs`:

# %%
pdos_plot.update_inputs(Erange=[-3, 3])
# Out:
# INFO	Task(Task-2) nodify.node.139647537924528:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538561536:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647637596848:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538571184:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538184112:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538561872:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538561536:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647637596848:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538291120:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538271520:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538267440:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538298704:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538268544:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538297216:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538179840:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538268544:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538288192:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538291360:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538267632:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538268544:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538283296:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538126656:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538564896:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538661616:node.py:get()- Evaluated because inputs changed.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="6fb867b4-c30d-4b90-8cd9-b5668082d10b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6fb867b4-c30d-4b90-8cd9-b5668082d10b")) {                    Plotly.newPlot(                        "6fb867b4-c30d-4b90-8cd9-b5668082d10b",                        [{"line":{"width":1.0},"meta":{},"mode":"lines","name":"DOS","x":{"dtype":"f8","bdata":"g2W2dYHsB8CB+iLjSbkHwG0o51EShgfAbb1Tv9pSB8BrUsAsox8HwFeAhJtr7AbAVxXxCDS5BsBDQ7V3\u002fIUGwEPYIeXEUgbAQW2OUo0fBsAtm1LBVewFwC0wvy4euQXAK8UrnOaFBcAX8+8Kr1IFwBeIXHh3HwXAA7Yg5z\u002fsBMABS41UCLkEwAHg+cHQhQTA7Q2+MJlSBMDroiqeYR8EwNnQ7gwq7APA12VbevK4A8DX+sfnuoUDwMMojFaDUgPAwb34w0sfA8Cv67wyFOwCwK2AKaDcuALAqxWWDaWFAsCZQ1p8bVICwJfYxuk1HwLAlW0zV\u002f7rAcCDm\u002ffFxrgBwIEwZDOPhQHAb14ooldSAcBt85QPIB8BwGuIAX3o6wDAWbbF67C4AMBXSzJZeYUAwEN59sdBUgDAQw5jNQofAMCCRp9Fpdf\u002fv1qiJyM2cf+\u002fWswA\u002fsYK\u002f78yKInbV6T+vy5SYrboPf6\u002fLnw7kXnX\u002fb8G2MNuCnH9vwYCnUmbCv2\u002fAix2JCyk\u002fL\u002fah\u002f4BvT38v9qx19xN1\u002fu\u002fsg1gut5w+7+uNzmVbwr7v65hEnAApPq\u002fhr2aTZE9+r+C53MoItf5v15D\u002fAWzcPm\u002fWm3V4EMK+b9Wl6671KP4vzLzNpllPfi\u002fLh0QdPbW978KeZhRh3D3vwajcSwYCve\u002fAs1KB6mj9r\u002feKNPkOT32v9pSrL\u002fK1vW\u002f1nyFmltw9b+y2A147An1v64C51J9o\u002fS\u002fhl5vMA499L+GiEgLn9bzv4KyIeYvcPO\u002fXg6qw8AJ879aOIOeUaPyvzKUC3ziPPK\u002fMr7kVnPW8b8u6L0xBHDxvwZERg+VCfG\u002fBm4f6iWj8L\u002feyafHtjzwv7TnAUWPrO+\u002ftDu0+rDf7r9k88S10hLuv1xHd2v0Re2\u002fXJspIRZ57L8MUzrcN6zrvwyn7JFZ3+q\u002fvF79THsS6r+0sq8CnUXpv7QGYri+eOi\u002fZL5yc+Cr579cEiUpAt\u002fmvxTKNeQjEua\u002fDB7omUVF5b8EcppPZ3jkv7wpqwqJq+O\u002ftH1dwKre4r9sNW57zBHiv2SJIDHuROG\u
CbriRE2SgFAJ1YdpG19AUA6KFk1pbABQDyT7Mfc4wFAPf5\u002fWhQXAkBQ0LvrS0oCQFI7T36DfQJAZA2LD7uwAkBmeB6i8uMCQGjjsTQqFwNAerXtxWFKA0B8IIFYmX0DQI\u002fyvOnQsANAkF1QfAjkA0CSyOMOQBcEQKWaH6B3SgRApgWzMq99BEC61+7D5rAEQLtCglYe5ARAvK0V6VUXBUDQf1F6jUoFQLmOwgzFfQVAW4nMnvywBUD9g9YwNOQFQLfaAsNrFwZAWdUMVaNKBkD7zxbn2n0GQJ3KIHkSsQZAP8UqC0rkBkDhvzSdgRcHQIS6Pi+5SgdAJrVIwfB9B0DIr1JTKLEHQIIGf+Vf5AdA"},"y":{"dtype":"f8","bdata":"LOQusngCoD8SXJIy7GOjP6JTAANg5aY\u002fvnw2E2ckqj8pDpIeaMOsPzLCECROea4\u002fcDWbqesfrz+hUgi12L2uP6Z3SJtHia0\u002fv5mT14fiqz8oIjypQkaqP\u002fiJY ...

# %% [markdown]
# <div class="alert alert-info">
#
# Don't worry!
#
# Each plot class has its own dedicated notebook in the documentation to guide you through all the knobs that they have!
#
# </div>

# %% [markdown]
# ## Different plotting backends
#
# Hidden between all the inputs, you can find a **very special input**: `backend`.
#
# This input allows you to choose the plotting backend used to display a plot. If you don't like the default one, just change it!

# %%
pdos_plot.update_inputs(backend="matplotlib")
# Out:
# INFO	Task(Task-2) nodify.node.139647537924528:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538561536:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647637596848:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538571184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538184112:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538561872:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538561536:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647637596848:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538291120:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538271520:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538267440:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538298704:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538268544:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538297216:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538179840:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538268544:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538288192:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538291360:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538267632:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538268544:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538283296:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538126656:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538564896:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538661616:node.py:get()- Evaluated because inputs changed.

# %% [markdown]
# Let's go back to the default one, `plotly`.

# %%
pdos_plot.update_inputs(backend="plotly")
# Out:
# INFO	Task(Task-2) nodify.node.139647537924528:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538561536:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647637596848:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538571184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538184112:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538561872:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538561536:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647637596848:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538291120:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538271520:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538267440:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538298704:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538268544:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538297216:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538179840:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538268544:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538288192:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538291360:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538267632:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538268544:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538283296:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538126656:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.139647538564896:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.139647538661616:node.py:get()- Evaluated because inputs changed.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="ebd173d9-244b-4c36-8502-070541657839" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ebd173d9-244b-4c36-8502-070541657839")) {                    Plotly.newPlot(                        "ebd173d9-244b-4c36-8502-070541657839",                        [{"line":{"width":1.0},"meta":{},"mode":"lines","name":" | species=Sr","x":{"dtype":"f8","bdata":"g2W2dYHsB8CB+iLjSbkHwG0o51EShgfAbb1Tv9pSB8BrUsAsox8HwFeAhJtr7AbAVxXxCDS5BsBDQ7V3\u002fIUGwEPYIeXEUgbAQW2OUo0fBsAtm1LBVewFwC0wvy4euQXAK8UrnOaFBcAX8+8Kr1IFwBeIXHh3HwXAA7Yg5z\u002fsBMABS41UCLkEwAHg+cHQhQTA7Q2+MJlSBMDroiqeYR8EwNnQ7gwq7APA12VbevK4A8DX+sfnuoUDwMMojFaDUgPAwb34w0sfA8Cv67wyFOwCwK2AKaDcuALAqxWWDaWFAsCZQ1p8bVICwJfYxuk1HwLAlW0zV\u002f7rAcCDm\u002ffFxrgBwIEwZDOPhQHAb14ooldSAcBt85QPIB8BwGuIAX3o6wDAWbbF67C4AMBXSzJZe