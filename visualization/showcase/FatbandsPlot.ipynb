# %% [markdown]
# [![GitHub issues by-label](https://img.shields.io/github/issues-raw/pfebrer/sisl/FatbandsPlot?style=for-the-badge)](https://github.com/pfebrer/sisl/labels/FatbandsPlot)

# %% [markdown]
#
#
# FatbandsPlot
# =========

# %%
import sisl

# %% [markdown]
# For this notebook we will create a toy "Boron nitride" tight binding:

# %%
# First, we create the geometry
BN = sisl.geom.graphene(atoms=["B", "N"])

# Create a hamiltonian with different on-site terms
H = sisl.Hamiltonian(BN)

H[0, 0] = 2
H[1, 1] = -2

H[0, 1] = -2.7
H[1, 0] = -2.7

H[0, 1, (-1, 0)] = -2.7
H[0, 1, (0, -1)] = -2.7
H[1, 0, (1, 0)] = -2.7
H[1, 0, (0, 1)] = -2.7

# %% [markdown]
# Note that we could have obtained this hamiltonian from any other source. Then we generate a path for the band structure:

# %%
band = sisl.BandStructure(
    H,
    [[0.0, 0.0], [2.0 / 3, 1.0 / 3], [1.0 / 2, 1.0 / 2], [1.0, 1.0]],
    301,
    [r"Gamma", "K", "M", r"Gamma"],
)

# %% [markdown]
# And finally we just ask for the fatbands plot:

# %%
fatbands = band.plot.fatbands()
fatbands

# %% [markdown]
# We only see the bands here, but this is a fatbands plot, and it is ready to accept your requests on what to draw!

# %% [markdown]
# ## Requesting specific weights
#
# The fatbands that the plot draws are controlled by the `groups` setting. This setting works exactly like the `groups` setting in `PdosPlot`, which is documented [here](./PdosPlot.ipynb). Therefore we won't give an extended description of it, but just quickly show that you can autogenerate the groups:

# %%
fatbands.split_orbs(on="species", name="$species")
# Out:
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320528:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841429600:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841427584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841327584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325040:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841432144:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320528:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841429600:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841430272:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841435984:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841432864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841431328:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841449632:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841328928:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841446320:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841452176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841435984:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841432144:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841448912:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841431088:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841449968:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841430752:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841447088:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841327584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325040:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841317888:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841317936:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841436176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841435456:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841449632:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841328928:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841446320:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841452176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841434256:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841452032:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841436176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841435648:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841313952:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841327584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325040:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320816:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325808:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841213280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841208576:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841210640:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841207376:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841451888:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841429936:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841429984:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841451936:node.py:get()- Evaluated because inputs changed.

# %% [markdown]
# Or write them yourself if you want the maximum flexibility:

# %%
fatbands.update_inputs(
    groups=[
        {"species": "N", "color": "blue", "name": "Nitrogen"},
        {"species": "B", "color": "red", "name": "Boron"},
    ]
)
# Out:
# INFO	Task(Task-2) nodify.node.140047841427584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841327584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325040:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841432144:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320528:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841429600:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841430272:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841435984:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841432864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841431328:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841449632:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841328928:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841446320:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841452176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841435984:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841432144:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841448912:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841431088:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841449968:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841430752:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841447088:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841327584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325040:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841317888:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841317936:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841436176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841435456:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841449632:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841328928:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841446320:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841452176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841434256:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841452032:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841436176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841435648:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841313952:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841327584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325040:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320816:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325808:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841213280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841208576:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841210640:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841207376:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841451888:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841429936:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841429984:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841451936:node.py:get()- Evaluated because inputs changed.

# %% [markdown]
# ## Scaling fatbands
#
# The visual appeal of fatbands depends a lot on the size of your plot, therefore there's one global `scale` setting that scales all fatbands at the same time:

# %%
fatbands.update_inputs(fatbands_scale=2).show("png")
# Out:
# INFO	Task(Task-2) nodify.node.140047841427584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841327584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325040:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841432144:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320528:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841429600:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841430272:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841435984:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841432864:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841431328:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841449632:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841328928:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841446320:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841452176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841435984:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841432144:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841448912:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841431088:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841449968:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841430752:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841447088:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841327584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325040:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841317888:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841317936:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841436176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841435456:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841449632:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841328928:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841446320:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841452176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841434256:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841452032:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841436176:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841435648:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841313952:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047912397392:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841318944:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841327584:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325040:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319184:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320864:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841320816:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841325808:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841213280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841208576:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841210640:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841207376:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841319280:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841451888:node.py:get()- No need to evaluate
# INFO	Task(Task-2) nodify.node.140047841429936:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841429984:node.py:get()- Evaluated because inputs changed.
# INFO	Task(Task-2) nodify.node.140047841451936:node.py:get()- Evaluated because inputs changed.

# %% [markdown]
# ## Use BandsPlot settings
#
# All settings of `BandsPlot` work as well for `FatbandsPlot`.
